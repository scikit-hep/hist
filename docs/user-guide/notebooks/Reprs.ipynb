# %%
from hist import Hist
import numpy as np

# %%
Hist.Reg(50, 1, 2).fill(np.random.normal(1.5, 0.3, 10_000))
# Out:
# Hist(Regular(50, 1, 2, label='Axis 0'), storage=Double()) # Sum: 8988.0 (10000.0 with flow)

# %%
Hist.Reg(50, 0, 2 * 3, circular=True).fill(np.random.normal(1.5, 0.7, 10_000))
# Out:
# Hist(Regular(50, 0, 6, circular=True, label='Axis 0'), storage=Double()) # Sum: 10000.0

# %%
Hist.Reg(50, 0, 2).Reg(50, 10, 20).fill(
    np.random.normal(1, 0.5, 10_000), np.random.normal(15, 3, 10_000)
)
# Out:
# Hist(
#   Regular(50, 0, 2, label='Axis 0'),
#   Regular(50, 10, 20, label='Axis 1'),
#   storage=Double()) # Sum: 8654.0 (10000.0 with flow)

# %%
Hist.Reg(50, 0, 2).Reg(50, 10, 20).Reg(2, 3, 4)
# Out:
# Hist(
#   Regular(50, 0, 2, label='Axis 0'),
#   Regular(50, 10, 20, label='Axis 1'),
#   Regular(2, 3, 4, label='Axis 2'),
#   storage=Double())
